# %% [markdown]
# ## HW#2: Visualizing Temperature Trends in Singapore
#
# ```{admonition} Objectives
# :class: tip
#
# This homework will help you gain a better understanding in terms of the ways how to:
# * Visualize the time series of temperature anomalies and its trend, and
# * Improve the data visualization.
#
# Happy coding!
# ```

# %% [markdown]
# ```{admonition} Submission Guide
#
# Deadline: **Sunday, 14th November 2021**
# (Note: Late submissions will not be accepted).
#
# Please upload your solutions to LumiNUS in a Jupyter Notebook format with the name "Homework2_StudentID.ipynb". Make sure to write down your student ID and full name in the cell below.
#
# For any questions, feel free to contact Prof. Xiaogang HE ([hexg@nus.edu.sg](mailto:hexg@nus.edu.sg)), Huimin WANG ([wanghuimin@u.nus.edu](mailto:wanghuimin@u.nus.edu)) or Zhanwei LIU ([liuzhanwei@u.nus.edu](mailto:liuzhanwei@u.nus.edu)).
#
# ```

# %%
### Fill your student ID and full name below.

# Student ID:
# Full name:

# %% [markdown]
# **Data**:
# You will need to use the historical (1982-2020) daily mean air temperature at Singapore's Changi station for this homework.
# You can create a DataFrame using Pandas by reading file "../../assets/data/Changi_daily_temperature.csv".

# %% [markdown]
# ### Q1: Visualize the time series of temperature anomaly
#
# Calculate the annual mean temperature. This will result in a data set of 39 values — one per year. Then, calculate the annual temperature anomalies using the first 10-years period as the baseline. To do this, you may need to (1) calculate the mean temperature over the first 10 years (1982—1991) as the baseline and (2) calculate the anomalies of each year's temperature to this baseline. Plot the line graph of the annual anomalies and make sure that correct  graph elements have been added, such as the title and the labels of both axes (Details on plotting in Python could be found in the `matplotlib` [tutorial](https://xiaoganghe.github.io/python-climate-visuals/chapters/data-visuals/matplotlib-basic.html#line-plots)). (40 marks)

# %%
# Your solutions go here.
# Use the + icon in the toolbar to add a cell.

# %% [markdown]
# ### Q2: Visualize the trend of temperature anomaly
#
# Based on the annual temperature anomalies in Q1, plot the trend of annual temperature anomalies using the 5-year moving average (30 marks).

# %%
# Your solutions go here.
# Use the + icon in the toolbar to add a cell.

# %% [markdown]
# ### Q3: Improve the visualization using the climate strips
#
# Add a climate strip graph as the background to improve the trend plot of Q2. A reference on the code to plot climate strips could be found at [this repository](https://github.com/josephshea/ClimateStripes/blob/master/ClimateStripes-Canada.ipynb) (30 marks).

# %%
# Your solutions go here.
# Use the + icon in the toolbar to add a cell.
