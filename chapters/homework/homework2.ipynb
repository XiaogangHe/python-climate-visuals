# %% [markdown]
# ## HW#2: Visualizing Historical Temperature Changes in Singapore
#
# ```{admonition} Objectives
# :class: tip
#
# This homework will provide you a real-world example in terms of:
# * how to visualize time series of temperature anomalies and its trend, and
# * how to make beautiful, understandable data visualizations.
#
# Happy coding!
# ```

# %% [markdown]
# ```{admonition} Submission Guide
#
# Deadline: **Sunday, 11:59 pm 14th November 2021**
# (Note: Late submissions will not be accepted).
#
# Please upload your solutions to LumiNUS in a Jupyter Notebook format with the name "Homework2_StudentID.ipynb". Make sure to write down your student ID and full name in the cell below.
#
# For any questions, feel free to contact Prof. Xiaogang HE ([hexg@nus.edu.sg](mailto:hexg@nus.edu.sg)), Huimin WANG ([wanghuimin@u.nus.edu](mailto:wanghuimin@u.nus.edu)) or Zhanwei LIU ([liuzhanwei@u.nus.edu](mailto:liuzhanwei@u.nus.edu)).
#
# ```

# %%
### Fill your student ID and full name below.

# Student ID:
# Full name:

# %% [markdown]
# **Data**:
# You will need to use the historical (1982-2020) daily mean air temperature data measured at Singapore's Changi station for this homework.
# You can create a DataFrame using Pandas by reading file "../../assets/data/Changi_daily_temperature.csv".

# %% [markdown]
# ### Q1: Visualize the time series of historical temperature anomalies of Singapore
#
# - Calculate the annual mean temperature from the daily data. This will result in a data set of 39 values — one per year.
# - Then, calculate the annual temperature anomalies using the first 10-year period as the baseline. To do this, you need to (1) calculate the decadal mean temperature over the first 10 years (1982—1991) and (2) calculate the annual anomalies of each year's temperature to this baseline.
# - Make a line graph of these annual anomalies and make sure that you have included necessary non-data elements, such as title, x/y axis labels, legend, etc (you can check the `matplotlib` [tutorial](https://xiaoganghe.github.io/python-climate-visuals/chapters/data-visuals/matplotlib-basic.html#line-plots) for details). (40 marks)

# %%
# Your solutions go here.
# Use the + icon in the toolbar to add a cell.

# %% [markdown]
# ### Q2: Visualize the trend of temperature anomaly
#
# Based on the annual temperature anomalies in Q1, visualize the trend of annual temperature anomalies using a 5-year moving window (30 marks).

# %%
# Your solutions go here.
# Use the + icon in the toolbar to add a cell.

# %% [markdown]
# ### Q3: Climate strips for Singapore
#
# - Reproduce the [climate strips](https://showyourstripes.info/s/asia/singapore) for Singapore.
# - Use the climate strips as the background and then overlay the time series of annual anomalies (from Q1) and the trend (from Q2) on top of the climate strips.
#
# Hint: (1) You can refer to [this GitHub repository](https://github.com/josephshea/ClimateStripes/blob/master/ClimateStripes-Canada.ipynb) to make the climate strips (30 marks). (2) To make a pretty chart, you might want to fine tune the aesthetics of your chart.

# %%
# Your solutions go here.
# Use the + icon in the toolbar to add a cell.
